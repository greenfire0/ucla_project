# %% [markdown]
# <a href="https://colab.research.google.com/github/greenfire0/ucla_project/blob/master/Apex_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
def load_housing_data(housing_path):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.DataFrame([
[479, 585, 663.66],
[1328, 696, 105.03],
[497,496, 351.26],
[407, 936, 81.02],
[922, 1246, 481.96],
[444, 760, 262.42],
[200, 1005, 252.33],
[311, 543, 82.85],
[943, 190, 1012.35],
[1062, 251, 789.97],
[193, 302, 457.15],
[1173, 1075, 496.88],
[465, 870, 66.64],
[738, 1221, 668.46],
[162, 939, 444.7],
[502, 500, 283.94],
[1159, 652, 591.13],
[722, 1293, 71.68],
[984, 1199, 138.41],
[461, 841, 119.17],
[287, 579, 578.06],
[797, 835, 74.72],
[1102, 648, 117.26],
[697, 635, 143.47],
[909, 1080, 318.98],
[773, 434, 410.97],
[177, 913, 768.59],
[592, 436, 211.28],
[894, 975, 451.58],
[795, 329, 382.91],
[471, 820, 83.78],
[1189, 858, 152.53],
[1119, 691, 127.27],
[899, 691, 109.07],
[1140, 675, 910.67],
[573, 254, 290.04],
[864, 1012, 105.02],
[457, 854, 74.67],
[1182, 658, 422.06],
[1004, 1154, 540.52],
[117, 1006, 55.71],
[729, 611, 350.41],
[1166, 643, 204.17],
[256, 1024, 519.05],
[866, 1003, 119.14],
[760, 350, 56.52],
[1085, 658, 249.52],
[167, 732, 1051.69],
[730, 444, 199.06],
[1078, 826, 762.96],
[976, 301, 411.34],
[868, 1008, 514.24],
[736, 1224, 190.94],
[488, 751, 138.41],
[461, 816, 179.77],
[480, 731, 422.32],
[652, 617, 297.92],
[716, 1218, 479.87],
[546, 285, 658.29],
[465, 796, 155.37],
[296, 586, 128.23],
[983, 1186, 633.45],
[835, 1033, 608.96],
[461, 767, 99.07],
[741, 597, 889.96],
[735, 1290, 189.93],
[1085, 658, 506.12],
[924, 458, 1279.59],
[798, 836, 275.56],
[846, 1001, 918.11],
[1178, 653, 719.9],
[991, 1214, 754.27],
[772, 468, 724.24],
[429, 909, 277.89],
[862, 1001, 180.81],
[476, 785, 620.15],
[459, 820, 235.1],
[456, 812, 267.78],
[401, 366, 514.25],
[766, 427, 109.07],
[635, 442, 707.04],
[499, 754, 338.28],
[882, 349, 1182.08],
[949, 1158, 176.69],
[609, 417, 917.68],
[942, 1073, 1357.67],
[125, 262, 291.19],
[484, 944, 94.02],
[642, 214, 501.37],
[1163, 642, 80.81],
[833, 1036, 140.47],
[1135, 619, 282.11],
[538, 320, 231.46],
[1166, 642, 423.44],
[900, 671, 205.24],
[766, 799, 281.01],
[399, 993, 573.6],
[729, 724, 857.66],
[479, 783, 624.23],
[466, 820, 624.23]

],        columns=('X', 'Y', 'time')
                 )

# %%
images_path = os.path.join('./', "/content/drive/MyDrive/Colab Notebooks/")
os.makedirs(images_path, exist_ok=True)
filename = "Olympus S08.jpg"
print(filename)

import matplotlib.image as mpimg
map_img=mpimg.imread(os.path.join(images_path, filename))
ax = apex.plot(kind="scatter", x="X", y="Y", figsize=(10,7), s=apex["time"], c="time",
                      
                        cmap=plt.get_cmap("jet"),
                       colorbar=False, alpha=0.5,
                      )

plt.imshow(map_img, extent=[0, 1500, 0, 1500], alpha=1,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Y", fontsize=14)
plt.xlabel("X", fontsize=14)

# setting up heatmap
alive = apex["time"]
tick_values = np.linspace(alive.min(), alive.max(), 11)
cb = plt.colorbar()
cb.ax.set_yticklabels(["%ds"%(round(v)) for v in tick_values], fontsize=14)
cb.set_label('Time_Alive', fontsize=16)


#plt.show()
# Out:
# Olympus S08.jpg
