# %% [markdown]
# <a href="https://colab.research.google.com/github/greenfire0/ucla_project/blob/master/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
import time

file= pd.read_csv("out.csv")


f = open('out222244.csv', "w+")
f.close()

df = pd.DataFrame()

spacer = pd.DataFrame()

for i in file[1:4]["url"]:
  r = requests.get(i)
  data = (r.text) 
  res = json.loads(str(data))
  df2 = pd.DataFrame((res["route"]["locations"]))
  print(df2)
  frames = [df, df2]
  df = pd.concat(frames)
print("****")
df.to_csv (r'out222244.csv', index = None)    







#change here too,just a name you want after it is converted
# Out:
#          0           1
# 0    62.07  [914, 989]
# 1    65.25  [910, 988]
# 2    68.74  [910, 989]
# 3    72.07  [909, 988]
# 4    75.43  [910, 990]
# 5    78.75  [910, 989]
# 6    81.77  [911, 989]
# 7    84.91  [913, 991]
# 8    88.08  [916, 990]
# 9    92.37  [916, 991]
# 10   96.05  [916, 993]
# 11   99.29  [916, 994]
# 12  102.65  [919, 992]
# 13  106.08  [919, 992]
# 14  109.24  [919, 992]
# 15  112.31  [916, 996]
# 16  115.34  [915, 998]
# 17  118.71  [918, 996]
# 18  122.08  [920, 998]
# 19  125.39  [920, 998]
# 20  128.42  [920, 998]
# 21  130.98  [920, 998]
#         0           1
# 0   25.79  [934, 784]
# 1   52.89  [560, 890]
# 2   55.99  [558, 886]
# 3   59.02  [561, 882]
# 4   62.05  [559, 889]
# 5   64.87  [554, 893]
# 6   68.25  [558, 901]
# 7   71.28  [560, 904]
# 8   74.31  [549, 899]
# 9   77.34  [536, 900]
# 10  80.81  [523, 904]
# 11  83.83  [520, 899]
# 12  87.15  [520, 899]
# 13  90.19  [523, 899]
# 14  93.43  [522, 902]
#          0           1
# ...

# %%
df1 = pd.DataFrame(df['route'].tolist())
print(df1)

ind = 0
for i in df1['map']:
  

  if i[:7] != "olympus":
    	#df.loc[row_indexer,column_indexer]
      print(i)
      df1 = (df1.drop(ind,axis=0))
  ind+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# kings_canyon.s8
# ...

# %% [markdown]
# df1.head()

# %%
import json
import pandas as pd

from pandas.io.json import json_normalize
#upload your file to google colab
#change the name out.json to file you want to convert



#change here too,just a name you want after it is converted
df1.to_csv (r'out.csv', index = None)

# %%
# !import json
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

ind=0
with open('/content/drive/MyDrive/out.json', "r") as file:
    f= json.load(file)
    df = pd.DataFrame(f['games'])
    df = pd.DataFrame(df[df['route'].notna()])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
import os

sns.set_theme(style="dark")

x = x1
y = y2


f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
import os
sns.set_theme(style="ticks")


x = x1
y = y2

import seaborn as sns
sns.set_theme(style="white")


sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")

# %%
with open('out.csv', "r") as file:
  df = pd.read_csv(file)
  print(type(df))
  x1 = []
  y2 = []
  print(df['landed_location'])
  for a in df['landed_location']:
    b = int(a.find(','))
    x1.append(float(a[1:b]))
    y2.append(float(a[b+2:len(a)-1]))
    #x.append)
df = pd.DataFrame({'x':x1, 'y':y2})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0         [255, 566]
# 1        [1071, 423]
# 2         [583, 438]
# 3         [480, 779]
# 4         [185, 952]
#             ...
# 22839    [720, 1224]
# 22840    [742, 1195]
# 22841    [1124, 677]
# 22842    [861, 1012]
# 22843    [1133, 622]
# Name: landed_location, Length: 22844, dtype: object
